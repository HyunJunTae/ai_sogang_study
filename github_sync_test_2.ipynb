# %%
# 1. 구글 드라이브 다시 연결 (팝업 뜨면 승인)
from google.colab import drive
drive.mount('/content/drive')

# 2. 우리 프로젝트 폴더로 위치 이동 (이게 핵심!)
import os
# %cd /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY

# %%
# !git config --global user.email "juny000041@gmail.com"
# !git config --global user.name "HyunJunTae"

# %%
# !git add .

# %%
# !git commit -m "기초 데이터 분석 및 seaborn, "
# Out:
# [main 1943951] pandas 강의 내용 정리 및 폴더 구조 업데이트
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  rename "ai_sogang_study/01_numpy/\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264\341\204\214\341\205\241\341\204\205\341\205\255 \341\204\206\341\205\251\341\204\213\341\205\263\341\206\267.ipynb" => "ai_sogang_study/\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264\341\204\214\341\205\241\341\204\205\341\205\255 \341\204\206\341\205\251\341\204\213\341\205\263\341\206\267.ipynb" (100%)

# %%
# 토큰은 아까 알려드린 코랩 '열쇠(Secrets)' 기능으로 불러와서 쓰시는 거 잊지 마세요!
from google.colab import userdata
t = userdata.get('github_ai_sogang_key') # 열쇠 아이콘에 설정한 이름

# !git remote set-url origin https://{t}@github.com/HyunJunTae/ai_sogang_study.git
# !git push origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.20 KiB | 76.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/HyunJunTae/ai_sogang_study.git
#    19b6cad..1943951  main -> main
