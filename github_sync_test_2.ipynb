# %%
# !git reset --hard origin/main
# Out:
# Updating files: 100% (28/28), done.
# HEAD is now at d59a600 코랩 깃헙 연동 성공

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	github_sync_test_2.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# 1. 구글 드라이브 다시 연결 (팝업 뜨면 승인)
from google.colab import drive
drive.mount('/content/drive')

# 2. 우리 프로젝트 폴더로 위치 이동 (이게 핵심!)
import os
# %cd /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY/.git/

# %%
# !git add .

# %%
# !git config --global user.email "juny000041@gmail.com"
# !git config --global user.name "HyunJunTae"

# %%
# !git commit -m "pandas 강의 내용 정리 및 폴더 구조 업데이트"
# Out:
# [main dca72f4] pandas 강의 내용 정리 및 폴더 구조 업데이트
#  2 files changed, 1 insertion(+), 2 deletions(-)
#  delete mode 100644 github_sync_test.ipynb
#  rewrite github_sync_test_2.ipynb (94%)

# %%
# 토큰은 아까 알려드린 코랩 '열쇠(Secrets)' 기능으로 불러와서 쓰시는 거 잊지 마세요!
from google.colab import userdata
t = userdata.get('github_ai_sogang_key') # 열쇠 아이콘에 설정한 이름

# !git remote set-url origin https://{t}@github.com/HyunJunTae/ai_sogang_study.git
# !git push origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.14 KiB | 72.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/HyunJunTae/ai_sogang_study.git
#    0357ded..dca72f4  main -> main

# %%
# !git check-ignore -v ai_sogang_study/02_pandas
