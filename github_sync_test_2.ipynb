# %%
# !git reset --hard origin/main
# Out:
# Updating files: 100% (28/28), done.
# HEAD is now at d59a600 코랩 깃헙 연동 성공

# %%
# !git status
# Out:
# On branch main
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	github_sync_test_2.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# 1. 구글 드라이브 다시 연결 (팝업 뜨면 승인)
from google.colab import drive
drive.mount('/content/drive')

# 2. 우리 프로젝트 폴더로 위치 이동 (이게 핵심!)
import os
# %cd /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/2026_1_AI_SOGANG_STUDY

# %%
# !git add .

# %%
# !git config --global user.email "juny000041@gmail.com"
# !git config --global user.name "HyunJunTae"

# %%
# !git commit -m "pandas 강의 내용 정리 및 폴더 구조 업데이트"
# Out:
# [main 19b6cad] pandas 강의 내용 정리 및 폴더 구조 업데이트
#  8 files changed, 8 insertions(+), 1 deletion(-)
#  create mode 100644 "ai_sogang_study/01_numpy/\341\204\200\341\205\241\341\206\274\341\204\213\341\205\264\341\204\214\341\205\241\341\204\205\341\205\255 \341\204\206\341\205\251\341\204\213\341\205\263\341\206\267.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 2\341\204\200\341\205\241\341\206\274.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 3\341\204\200\341\205\241\341\206\274.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 4\341\204\200\341\205\241\341\206\274.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 5\341\204\200\341\205\241\341\206\274.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 6\341\204\200\341\205\241\341\206\274.ipynb"
#  create mode 100644 "ai_sogang_study/02_pandas/pandas \341\204\200\341\205\241\341\206\274\341\204\213\341\205\264 8\341\204\200\341\205\241\341\206\274.ipynb"
#  rewrite github_sync_test_2.ipynb (77%)

# %%
# 토큰은 아까 알려드린 코랩 '열쇠(Secrets)' 기능으로 불러와서 쓰시는 거 잊지 마세요!
from google.colab import userdata
t = userdata.get('github_ai_sogang_key') # 열쇠 아이콘에 설정한 이름

# !git remote set-url origin https://{t}@github.com/HyunJunTae/ai_sogang_study.git
# !git push origin main
# Out:
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 24.51 KiB | 291.00 KiB/s, done.
# Total 13 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 3 local objects.
# To https://github.com/HyunJunTae/ai_sogang_study.git
#    5ae9aa7..19b6cad  main -> main
