# %%
import pandas as pd

# %%
import numpy as np

# %%
a = np.random.randint(0, 10, 24).reshape(4, 6)
df = pd.DataFrame(a, index = list("가나다라"), columns = list("ABCDEF"))

# %%
df
# Out:
#    A  B  C  D  E  F
# 가  5  6  5  5  6  4
# 나  3  8  8  1  6  9
# 다  6  9  2  5  6  4
# 라  1  6  0  1  4  9

# %%
df
# Out:
#    A  B  C  D  E  F
# 가  5  6  5  5  6  4
# 나  3  8  8  1  6  9
# 다  6  9  2  5  6  4
# 라  1  6  0  1  4  9

# %%
df[0:1]
# Out:
#    A  B  C  D  E  F
# 가  5  6  5  5  6  4

# %%
df["A"]
# Out:
# 가    5
# 나    3
# 다    6
# 라    1
# Name: A, dtype: int64

# %%
df.loc["가":"다", "A" : "E"]
# Out:
#    A  B  C  D  E
# 가  5  6  5  5  6
# 나  3  8  8  1  6
# 다  6  9  2  5  6

# %%
df.loc["가":"다", ["A", "E", "E"]]
# Out:
#    A  E  E
# 가  5  6  6
# 나  3  6  6
# 다  6  6  6

# %%
df.loc[["가"]]
# Out:
#    A  B  C  D  E  F
# 가  5  6  5  5  6  4
