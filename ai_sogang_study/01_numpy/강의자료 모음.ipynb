# %% [markdown]
# 🗓️ Sprint 1 일정
# 기간: 3월 8일(일) ~ 3월 11일(수) (12일에는 새로운 자료를 드릴 예정입니다)
#
# ✅ 아래 내용을 체크하며 공부해보시기 바랍니다
# <numpy>
# : 선형대수 연산이 넘파이의 본질이라는 것을 인식하고 공부
# ndarray 개념 (shape, dtype)
# 벡터/행렬 연산 감각
#
# <opencv>
# : 카메라 입력 -> 이미지(=numpy 배열)로 변환해주는 라이브러리. opencv에서 읽는 이미지는 np.ndarray
# 좌표계 감각 익히기
# 이미지 처리 연산 이해 (이미지 처리 = 배열연산)
#
# 📚 학습 자료
# 강의: 1번부터 11번 영상까지 시청
# https://youtube.com/playlist?list=PLRx0vPvlEmdBx9X5xSgcEk4CEbzEiws8C&si=j_XpYM51v4-qPjr3
# 자료:
# https://github.com/ndb796/Python-Data-Analysis-and-Image-Processing-Tutorial

# %% [markdown]
# Sprint 2. Pandas
# 기간: 3/14(토)-3/18(수)
#
# 자료 1. pandas 기초 강의
# https://youtube.com/playlist?list=PLrpXwtuxGqcIIf_SpCWg04MoHf1yJUCvi&si=ghNbsEd2pfc9_KYV
#
# 자료 2. pandas 위키독스 자료
# https://wikidocs.net/213826
#
# 자료1을 통해 판다스가 무엇인지 기초를 익힌 뒤, 자료 2를 통해 직접 실습해보시길 바랍니다.
# 실습 환경은 Colab을 추천드립니다.
#
# 공지 채널에 말한 4가지를 학습하기에 자료가 충분치 않다고 판단되면 직접 다른 자료를 추가적으로 찾아 공부해보시길 바랍니다!
# 좋은 자료를 발견했다면 사담방에 올려주셔도 좋습니다 🙂
